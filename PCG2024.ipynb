# %% [markdown]
# <a href="https://colab.research.google.com/github/Pedrosimoes12/PCG2024/blob/main/PCG2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/SEEG.csv", sep=";")

# %%
df2 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/tabela6588.csv", sep=';')

# %% [markdown]
#   A função .T transpõe a tabela
#
#   A função reset_index apaga o índice da tabela

# %%
df1 = df1.T
df1 = df1.reset_index()

# %% [markdown]
# Aqui está sendo adicionado o novo índice e apagado a linha com o índice anterior que estava errado
#
# > Adicionar aspas

# %%
df1.columns = ['Ano', 'Produção_de_CO2']
df1 = df1.drop(0)
display(df1)
# Out:
#      Ano Produção_de_CO2
# 1   2013     33599928.39
# 2   2014     32279299.57
# 3   2015     32488950.52
# 4   2016     35428697.77
# 5   2017     35901230.17
# 6   2018     34882317.43
# 7   2019     34328032.59
# 8   2020     35177751.93
# 9   2021     35510514.11
# 10  2022     35685075.89

# %% [markdown]
# Aqui está sendo feito a mesma coisa com o segundo dataset

# %%
df2 = df2.T
df2 = df2.reset_index()

# %%
df2.columns = ['Ano', 'Área_plantada']
df2 = df2.drop(0)
display(df2)
# Out:
#         Ano Área_plantada
# 1    jan/13       7419734
# 2    fev/13       8434862
# 3    mar/13       8434862
# 4    abr/13       8434862
# 5    mai/13       8434862
# ..      ...           ...
# 128  ago/23       8001135
# 129  set/23       7852134
# 130  out/23       7852134
# 131  nov/23       7852134
# 132  dez/23       7754021
#
# [132 rows x 2 columns]

# %% [markdown]
# Aqui está sendo selecionado um ano por vez dentro do "for" e calculando a média desse determinado ano e a armazenando dentro de uma lista.

# %%
i = 0
year = 13
media = []
for i in range (10):
   ano = df2.loc[df2["Ano"].str.contains(f'/{year}')]
   display(ano)
   media.append(ano.Área_plantada.mean())
   year = year + 1

display(media)
# Out:
#        Ano Área_plantada
# 1   jan/13       7419734
# 2   fev/13       8434862
# 3   mar/13       8434862
# 4   abr/13       8434862
# 5   mai/13       8434862
# 6   jun/13       7818388
# 7   jul/13       7818388
# 8   ago/13       7818388
# 9   set/13       8054291
# 10  out/13       8054291
# 11  nov/13       8054291
# 12  dez/13       8373829
#        Ano Área_plantada
# 13  jan/14       8263641
# 14  fev/14       8202188
# 15  mar/14       7978897
# 16  abr/14       7978897
# 17  mai/14       7978897
# 18  jun/14       7978897
# 19  jul/14       7921670
# 20  ago/14       7921670
# 21  set/14       7921670
# 22  out/14       7989437
# 23  nov/14       7998991
# 24  dez/14       7993149
#        Ano Área_plantada
# 25  jan/15       8050154
# 26  fev/15       7758781
# 27  mar/15       7758781
# 28  abr/15       7758781
# 29  mai/15       7758781
# 30  jun/15       7758781
# 31  jul/15       8314175
# 32  ago/15       8314175
# 33  set/15       8314175
# 34  out/15       8145392
# 35  nov/15       8161505
# 36  dez/15       8746681
#        Ano Área_plantada
# 37  jan/16       7788028
# 38  fev/16       8794642
# 39  mar/16       8794642
# 40  abr/16       8794642
# 41  mai/16       8794642
# 42  jun/16       8794642
# 43  jul/16       8390479
# 44  ago/16       8390479
# 45  set/16       8326044
# 46  out/16       8327044
# 47  nov/16       8327044
# 48  dez/16       8341130
#        Ano Área_plantada
# 49  jan/17       7777389
# 50  fev/17       7777389
# 51  mar/17       7777389
# 52  abr/17       8146112
# 53  mai/17       8168551
# 54  jun/17       8185747
# 55  jul/17       8524177
# 56  ago/17       8524177
# 57  set/17       9019271
# 58  out/17       9019271
# 59  nov/17       9019271
# 60  dez/17       8251089
#        Ano Área_plantada
# 61  jan/18       7987615
# 62  fev/18       7987615
# 63  mar/18       7987615
# 64  abr/18       8631356
# 65  mai/18       8623356
# 66  jun/18       8532057
# 67  jul/18       8520792
# 68  ago/18       8520792
# 69  set/18       8352106
# 70  out/18       8352106
# 71  nov/18       8352106
# 72  dez/18       8346759
#        Ano Área_plantada
# 73  jan/19       8283923
# 74  fev/19       8283923
# 75  mar/19       8177371
# 76  abr/19       8177371
# 77  mai/19       8177371
# 78  jun/19       8129592
# 79  jul/19       8129592
# 80  ago/19       8129592
# 81  set/19       8143150
# 82  out/19       8143150
# 83  nov/19       8143150
# 84  dez/19       8172747
#        Ano Área_plantada
# 85  jan/20       8178418
# 86  fev/20       8178418
# 87  mar/20       8178418
# 88  abr/20       8178418
# 89  mai/20       8178418
# 90  jun/20       8341445
# 91  jul/20       8341445
# 92  ago/20       8341445
# 93  set/20       8280919
# 94  out/20       8280919
# 95  nov/20       8280919
# 96  dez/20       8375834
#         Ano Área_plantada
# 97   jan/21       8409861
# 98   fev/21       8409861
# 99   mar/21       8409861
# 100  abr/21       8287619
# 101  mai/21       8287619
# 102  jun/21       8287619
# 103  jul/21       8287619
# 104  ago/21       8287619
# 105  set/21       8180663
# 106  out/21       8180663
# 107  nov/21       8180663
# 108  dez/21       7558095
#         Ano Área_plantada
# 109  jan/22       8641014
# 110  fev/22       8641014
# 111  mar/22       8641014
# 112  abr/22       8592522
# 113  mai/22       8592522
# 114  jun/22       8592522
# 115  jul/22       7483751
# 116  ago/22       7483751
# 117  set/22       7450890
# 118  out/22       7450890
# 119  nov/22       7719288
# 120  dez/22       7719288
# [8095920.666666667,
#  8010667.0,
#  8070013.5,
#  8488621.5,
#  8349152.75,
#  8349522.916666667,
#  8174244.333333333,
#  8261251.333333333,
#  8230646.833333333,
#  8084038.833333333]

# %% [markdown]
# Aqui está sendo criado o dataframe que possui a média anual da área plantada e a produção de CO2 do estado de São Paulo

# %%
relacao_df = pd.DataFrame()

# %% [markdown]
# Com a funçao insert está pegando a coluna "Ano" do dataframe 1 e adicionado no novo dataframe
#
# A função loc está criando uma coluna e completando com as informações da lista média
#
# O ultimo insert está pegando a coluna "Produção_de_CO2" do primeiro dataframe e
# copiando ela na terceira coluna do terceiro dataframe

# %%
relacao_df.insert(0, 'Ano', df1['Ano'])
relacao_df.loc[:,"Media_Area_Plantada"] = media
relacao_df.insert(2, 'Produção_de_CO2', df1['Produção_de_CO2'])

# %%
display(relacao_df)
# Out:
#      Ano  Media_Area_Plantada Produção_de_CO2
# 1   2013         8.095921e+06     33599928.39
# 2   2014         8.010667e+06     32279299.57
# 3   2015         8.070014e+06     32488950.52
# 4   2016         8.488622e+06     35428697.77
# 5   2017         8.349153e+06     35901230.17
# 6   2018         8.349523e+06     34882317.43
# 7   2019         8.174244e+06     34328032.59
# 8   2020         8.261251e+06     35177751.93
# 9   2021         8.230647e+06     35510514.11
# 10  2022         8.084039e+06     35685075.89

# %% [markdown]
# Esta célula está produzindo um gráfico da média da área plantada de SP dos anos de 2013 a 2022
#
# Ela utiliza funções do matplotlib, uma biblioteca específica para gráficos, a função "_plot_series" utiliza os valores do dataframe "relacao_df" pegando os dados da coluna "Ano" e armazenando no eixo X e os dados da coluna "Media_Area_Plantada" no eixo Y, tambem é utilizado da biblioteca seanborn para determinar a cor da linha do grafico e o comando plt.plot para exibir o grafico
#
# As linhas fora da função determinam o estilo de gráfico e a forma que ele é apresentado

# %%
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Ano']
  ys = series['Media_Area_Plantada']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = relacao_df.sort_values('Ano', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Ano')
_ = plt.ylabel('Media_Area_Plantada')

# %% [markdown]
# Está célula faz a mesma coisa que a célula anterior, mas produz um gráfico da Produção de CO2 no estado de São Paulo nos anos de 2013 a 2022

# %%
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.color_palette("husl", 8))
  xs = series['Ano']
  ys = series['Produção_de_CO2']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = relacao_df.sort_values('Ano', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Ano')
_ = plt.ylabel('Produção_de_CO2')

# %%
def _plot_series(series, series_name, series_index=0):
  xs = series['Ano']
  ys = series['Media_Area_Plantada']
  xs2 = series['Ano']
  ys2 = series['Produção_de_CO2']

  palette = list(sns.palettes.mpl_palette('Dark2'))
  plt.plot(xs, ys, label='Media_Area_Plantada', color=palette[series_index % len(palette)])
  palette = list(sns.color_palette("husl", 8))
  plt.plot(xs2, ys2, label='Produção_de_CO2', color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = relacao_df.sort_values('Ano', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Ano')
plt.ylabel('Valores')
plt.legend()
plt.show()
